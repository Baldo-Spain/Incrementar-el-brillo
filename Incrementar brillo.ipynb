# %% [markdown]
# # Operaciones aritméticas.
# Multiplicar por un escalar para incrementar brillo

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
from IPython.display import Image

# %%
image = 'malaga.jpg'
img = cv2.imread(image, cv2.IMREAD_COLOR)
print(img.shape)
print(img.dtype)
# Out:
# (427, 640, 3)
# uint8

# %%
# Recordamos que opencv usa caneles bgr asi que convertimos a RGB
img = img[:,:,::-1]

# y mostramos
plt.imshow(img);

# %%
# Aplicamos a la imagen original un factor para incrementar o reducir los valores
img_up = cv2.multiply(img, 1.3)
img_down = cv2.multiply(img, 0.7)

fig, axs = plt.subplots(1, 3, figsize=(18, 5))
axs[0].imshow(img_up)
axs[0].set_title("Más brillo",fontsize=16) 

axs[1].imshow(img)
axs[1].set_title("Original",fontsize=16)

axs[2].imshow(img_down)
axs[2].set_title("Más oscura",fontsize=16);

# %%
# Ejercicio 1

# Importa la imagen "carmen.jpg"

# Corrige los colores 

# Visualiza la imagen

# %%
# Ejercicio 2

# Crea carmen_up utilizando carmen y un factor multiplicativo de 1.2

# Crea carmen_down utilizando carmen y un factor reductor de 0.8

# %%
# Muestra las 3 figuras en orden

# fig, axs = plt.subplots(1, 3, figsize=(18, 5))
